# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\sunil\Desktop\Machine_Learnig\Datasets\train.csv")
df.head()
# Out:
#   Cell In[8], line 1
#     pd.read_csv("C:\Users\sunil\Desktop\Machine_Learnig\Datasets\train.csv")
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
