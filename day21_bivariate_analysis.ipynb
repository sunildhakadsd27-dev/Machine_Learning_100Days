# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tatinic = pd.read_csv("C:\\Users\\sunil\\OneDrive\\Desktop\\OneDrive\\Desktop\\Machine_Learnig\\Datasets\\train.csv")
tatinic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# 1. Scatterplot (Numerical - Numerical)

# %%
# bivariate analysis
sns.relplot(data=tips, x='tip', y='total_bill', height=4, aspect=1.5)

# %%
# This works perfectly with height and aspect
sns.relplot(data=tips,x='total_bill',y='tip',hue='sex',style='smoker',size="size",kind="scatter", height=4, aspect=1.5)

# %%
sns.barplot(data=tatinic,x='Pclass',y='Age',hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# 2. Bar Plot (Numerical - Categorical)

# %%
tatinic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(data=tatinic,x='Pclass',y='Survived',hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.boxplot(data=tatinic,x='Sex',y='Age',hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# EDA Project

# %%
df  = pd.read_csv("C:\\Users\\sunil\\OneDrive\\Desktop\\OneDrive\\Desktop\\Machine_Learnig\\Datasets\\India_Real_Budget_1947_2026.csv")

# %%
df.head()
# Out:
#    Year  Defense_Percentage  Education_Percentage  Health_Percentage  \
# 0  1947               14.78                 13.32               3.05
# 1  1948               14.78                 13.32               3.05
# 2  1949               14.78                 13.32               3.05
# 3  1950               14.78                 13.32               3.05
# 4  1951               14.78                 13.32               3.05
#
#    Interest_Payments_Percentage  Total_Budget_Billions_USD  \
# 0                         11.31                      3.346
# 1                         11.31                      3.514
# 2                         11.31                      3.690
# 3                         11.31                      3.874
# 4                         11.31                      4.068
#
#    Infrastructure_Percentage  Agriculture_Percentage  \
# 0                      17.26                    8.63
# 1                      17.26                    8.63
# ...

# %%
df.tail()
# Out:
#     Year  Defense_Percentage  Education_Percentage  Health_Percentage  \
# 75  2022                7.99                 14.16               4.71
# 76  2023                7.90                 14.16               4.59
# 77  2024                7.63                 14.16               4.59
# 78  2025                7.63                 14.16               4.59
# 79  2026                7.63                 14.16               4.59
#
#     Interest_Payments_Percentage  Total_Budget_Billions_USD  \
# 75                         23.23                    870.609
# 76                         23.23                    937.840
# 77                         23.23                   1007.465
# 78                         23.23                   1059.771
# 79                         23.23                   1155.150
#
#     Infrastructure_Percentage  Agriculture_Percentage  \
# 75                      14.97                    7.49
# 76                      15.04                    7.52
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Defense_Percentage', 'Education_Percentage',
#        'Health_Percentage', 'Interest_Payments_Percentage',
#        'Total_Budget_Billions_USD', 'Infrastructure_Percentage',
#        'Agriculture_Percentage', 'State_Transfers_Percentage',
#        'Social_Welfare_Percentage', 'Administration_and_Others_Percentage',
#        'Defense_Amount_Billions_USD', 'Education_Amount_Billions_USD',
#        'Health_Amount_Billions_USD', 'Interest_Payments_Amount_Billions_USD',
#        'Infrastructure_Amount_Billions_USD', 'Agriculture_Amount_Billions_USD',
#        'State_Transfers_Amount_Billions_USD',
#        'Social_Welfare_Amount_Billions_USD',
#        'Administration_and_Others_Amount_Billions_USD'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 20 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Year                                           80 non-null     int64
#  1   Defense_Percentage                             80 non-null     float64
#  2   Education_Percentage                           80 non-null     float64
#  3   Health_Percentage                              80 non-null     float64
#  4   Interest_Payments_Percentage                   80 non-null     float64
#  5   Total_Budget_Billions_USD                      80 non-null     float64
#  6   Infrastructure_Percentage                      80 non-null     float64
#  7   Agriculture_Percentage                         80 non-null     float64
#  8   State_Transfers_Percentage                     80 non-null     float64
# ...

# %%
df.describe().T
# Out:
#                                                count         mean         std  \
# Year                                            80.0  1986.500000   23.237900
# Defense_Percentage                              80.0    12.386500    2.688018
# Education_Percentage                            80.0    13.520125    1.142745
# Health_Percentage                               80.0     3.198000    0.441976
# Interest_Payments_Percentage                    80.0    17.827625    6.293540
# Total_Budget_Billions_USD                       80.0   221.161600  312.662464
# Infrastructure_Percentage                       80.0    15.920125    1.439323
# Agriculture_Percentage                          80.0     7.959875    0.719681
# State_Transfers_Percentage                      80.0     7.959875    0.719681
# Social_Welfare_Percentage                       80.0     7.959875    0.719681
# Administration_and_Others_Percentage            80.0    13.265250    1.198611
# ...

# %%
df.isnull().sum()
(df.isnull().sum()/len(df))*100
# Out:
# Year                                             0.0
# Defense_Percentage                               0.0
# Education_Percentage                             0.0
# Health_Percentage                                0.0
# Interest_Payments_Percentage                     0.0
# Total_Budget_Billions_USD                        0.0
# Infrastructure_Percentage                        0.0
# Agriculture_Percentage                           0.0
# State_Transfers_Percentage                       0.0
# Social_Welfare_Percentage                        0.0
# Administration_and_Others_Percentage             0.0
# Defense_Amount_Billions_USD                      0.0
# Education_Amount_Billions_USD                    0.0
# Health_Amount_Billions_USD                       0.0
# Interest_Payments_Amount_Billions_USD            0.0
# Infrastructure_Amount_Billions_USD               0.0
# Agriculture_Amount_Billions_USD                  0.0
# State_Transfers_Amount_Billions_USD              0.0
# ...

# %%
sns.heatmap(df.isnull(),cbar=False)
# Out:
# <Axes: >

# %%
df.duplicated().sum()
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year, Defense_Percentage, Education_Percentage, Health_Percentage, Interest_Payments_Percentage, Total_Budget_Billions_USD, Infrastructure_Percentage, Agriculture_Percentage, State_Transfers_Percentage, Social_Welfare_Percentage, Administration_and_Others_Percentage, Defense_Amount_Billions_USD, Education_Amount_Billions_USD, Health_Amount_Billions_USD, Interest_Payments_Amount_Billions_USD, Infrastructure_Amount_Billions_USD, Agriculture_Amount_Billions_USD, State_Transfers_Amount_Billions_USD, Social_Welfare_Amount_Billions_USD, Administration_and_Others_Amount_Billions_USD]
# Index: []

# %%
df.dtypes
# Out:
# Year                                               int64
# Defense_Percentage                               float64
# Education_Percentage                             float64
# Health_Percentage                                float64
# Interest_Payments_Percentage                     float64
# Total_Budget_Billions_USD                        float64
# Infrastructure_Percentage                        float64
# Agriculture_Percentage                           float64
# State_Transfers_Percentage                       float64
# Social_Welfare_Percentage                        float64
# Administration_and_Others_Percentage             float64
# Defense_Amount_Billions_USD                      float64
# Education_Amount_Billions_USD                    float64
# Health_Amount_Billions_USD                       float64
# Interest_Payments_Amount_Billions_USD            float64
# Infrastructure_Amount_Billions_USD               float64
# ...

# %%
num_cols=df.select_dtypes(include='number').columns
cat_cols=df.select_dtypes(include='object').columns

# %%
df.describe().T
# Out:
#                                                count         mean         std  \
# Year                                            80.0  1986.500000   23.237900
# Defense_Percentage                              80.0    12.386500    2.688018
# Education_Percentage                            80.0    13.520125    1.142745
# Health_Percentage                               80.0     3.198000    0.441976
# Interest_Payments_Percentage                    80.0    17.827625    6.293540
# Total_Budget_Billions_USD                       80.0   221.161600  312.662464
# Infrastructure_Percentage                       80.0    15.920125    1.439323
# Agriculture_Percentage                          80.0     7.959875    0.719681
# State_Transfers_Percentage                      80.0     7.959875    0.719681
# Social_Welfare_Percentage                       80.0     7.959875    0.719681
# Administration_and_Others_Percentage            80.0    13.265250    1.198611
# ...

# %%
for col in df.columns:
    print(col,df[col].nunique())
# Out:
# Year 80
# Defense_Percentage 35
# Education_Percentage 20
# Health_Percentage 23
# Interest_Payments_Percentage 46
# Total_Budget_Billions_USD 80
# Infrastructure_Percentage 47
# Agriculture_Percentage 45
# State_Transfers_Percentage 45
# Social_Welfare_Percentage 45
# Administration_and_Others_Percentage 46
# Defense_Amount_Billions_USD 80
# Education_Amount_Billions_USD 80
# Health_Amount_Billions_USD 79
# Interest_Payments_Amount_Billions_USD 80
# Infrastructure_Amount_Billions_USD 80
# Agriculture_Amount_Billions_USD 80
# State_Transfers_Amount_Billions_USD 80
# Social_Welfare_Amount_Billions_USD 80
# Administration_and_Others_Amount_Billions_USD 80

# %%
sns.boxplot(x=df['Total_Budget_Billions_USD'])
# Out:
# <Axes: xlabel='Total_Budget_Billions_USD'>

# %%
sns.kdeplot(df['Total_Budget_Billions_USD'])
# Out:
# <Axes: xlabel='Total_Budget_Billions_USD', ylabel='Density'>

# %%
df.skew(numeric_only=True)
df.kurt(numeric_only=True)
# Out:
# Year                                            -1.200000
# Defense_Percentage                              -1.588133
# Education_Percentage                             2.107295
# Health_Percentage                                5.265767
# Interest_Payments_Percentage                    -1.305144
# Total_Budget_Billions_USD                        0.961531
# Infrastructure_Percentage                        0.130786
# Agriculture_Percentage                           0.122245
# State_Transfers_Percentage                       0.122245
# Social_Welfare_Percentage                        0.122245
# Administration_and_Others_Percentage             0.129883
# Defense_Amount_Billions_USD                      0.148198
# Education_Amount_Billions_USD                    0.991201
# Health_Amount_Billions_USD                       2.866902
# Interest_Payments_Amount_Billions_USD            1.613363
# Infrastructure_Amount_Billions_USD               0.748716
# ...

# %%
plt.figure(figsize=(12,5))

sns.lineplot(
data=df,
x='Year',
y='Total_Budget_Billions_USD')
# Out:
# <Axes: xlabel='Year', ylabel='Total_Budget_Billions_USD'>

# %%
sns.lineplot(
data=df,
x='Year',
y='Defense_Amount_Billions_USD')
# Out:
# <Axes: xlabel='Year', ylabel='Defense_Amount_Billions_USD'>

# %%
sns.lineplot(
data=df,
x='Year',
y='Education_Amount_Billions_USD')
# Out:
# <Axes: xlabel='Year', ylabel='Education_Amount_Billions_USD'>

# %%
sns.lineplot(
data=df,
x='Year',
y='Health_Amount_Billions_USD')
# Out:
# <Axes: xlabel='Year', ylabel='Health_Amount_Billions_USD'>

# %%
sns.lineplot(
data=df,
x='Year',
y='Infrastructure_Amount_Billions_USD')
# Out:
# <Axes: xlabel='Year', ylabel='Infrastructure_Amount_Billions_USD'>

# %%
plt.figure(figsize=(18,10))

sns.heatmap(
df.corr(numeric_only=True),
annot=True,
cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.scatterplot(
data=df,
x='Total_Budget_Billions_USD',
y='Defense_Amount_Billions_USD')
# Out:
# <Axes: xlabel='Total_Budget_Billions_USD', ylabel='Defense_Amount_Billions_USD'>

# %%
sns.scatterplot(
data=df,
x='Total_Budget_Billions_USD',
y='Education_Amount_Billions_USD')
# Out:
# <Axes: xlabel='Total_Budget_Billions_USD', ylabel='Education_Amount_Billions_USD'>

# %%
sns.lineplot(
data=df,
x='Year',
y='Health_Amount_Billions_USD')
# Out:
# <Axes: xlabel='Year', ylabel='Health_Amount_Billions_USD'>

# %%
cols=[
'Total_Budget_Billions_USD',
'Defense_Amount_Billions_USD',
'Education_Amount_Billions_USD',
'Health_Amount_Billions_USD',
'Infrastructure_Amount_Billions_USD'
]

sns.pairplot(df[cols])

# %%
plt.figure(figsize=(14,6))

plt.plot(df['Year'],df['Defense_Amount_Billions_USD'],label='Defense')
plt.plot(df['Year'],df['Education_Amount_Billions_USD'],label='Education')
plt.plot(df['Year'],df['Health_Amount_Billions_USD'],label='Health')
plt.plot(df['Year'],df['Infrastructure_Amount_Billions_USD'],label='Infrastructure')

plt.legend()
plt.show()

# %%
sns.lineplot(
data=df,
x='Year',
y='Defense_Percentage')
# Out:
# <Axes: xlabel='Year', ylabel='Defense_Percentage'>

# %%
df.nlargest(10,'Total_Budget_Billions_USD')
# Out:
#     Year  Defense_Percentage  Education_Percentage  Health_Percentage  \
# 79  2026                7.63                 14.16               4.59
# 78  2025                7.63                 14.16               4.59
# 77  2024                7.63                 14.16               4.59
# 76  2023                7.90                 14.16               4.59
# 75  2022                7.99                 14.16               4.71
# 74  2021                8.04                 14.92               4.46
# 71  2018                9.10                 16.64               3.68
# 70  2017                9.39                 15.81               3.66
# 72  2019                9.32                 14.82               3.85
# 73  2020                8.76                 15.99               3.69
#
#     Interest_Payments_Percentage  Total_Budget_Billions_USD  \
# 79                         23.23                   1155.150
# 78                         23.23                   1059.771
# ...

# %%
top=df.nlargest(10,'Total_Budget_Billions_USD')

sns.barplot(
data=top,
x='Year',
y='Total_Budget_Billions_USD')
# Out:
# <Axes: xlabel='Year', ylabel='Total_Budget_Billions_USD'>

# %%
df.nsmallest(10,'Total_Budget_Billions_USD')
# Out:
#    Year  Defense_Percentage  Education_Percentage  Health_Percentage  \
# 0  1947               14.78                 13.32               3.05
# 1  1948               14.78                 13.32               3.05
# 2  1949               14.78                 13.32               3.05
# 3  1950               14.78                 13.32               3.05
# 4  1951               14.78                 13.32               3.05
# 5  1952               14.78                 13.32               3.05
# 6  1953               14.78                 13.32               3.05
# 7  1954               14.78                 13.32               3.05
# 8  1955               14.78                 13.32               3.05
# 9  1956               14.78                 13.32               3.05
#
#    Interest_Payments_Percentage  Total_Budget_Billions_USD  \
# 0                         11.31                      3.346
# 1                         11.31                      3.514
# ...

# %%
df['Budget_Growth_%']=df['Total_Budget_Billions_USD'].pct_change()*100

# %%
df['Budget_Growth_%'] = df['Total_Budget_Billions_USD'].pct_change()*100

plt.figure(figsize=(14,5))
sns.lineplot(data=df, x='Year', y='Budget_Growth_%')
plt.title("Year-on-Year Budget Growth")
plt.grid(True)
plt.show()

# %%
start = df['Total_Budget_Billions_USD'].iloc[0]
end = df['Total_Budget_Billions_USD'].iloc[-1]
years = len(df)-1

cagr = ((end/start)**(1/years)-1)*100

print(f"CAGR = {cagr:.2f}%")
# Out:
# CAGR = 7.68%

# %%
df['Rolling_5Y'] = df['Total_Budget_Billions_USD'].rolling(5).mean()

plt.figure(figsize=(14,5))
plt.plot(df['Year'], df['Total_Budget_Billions_USD'], label='Actual')
plt.plot(df['Year'], df['Rolling_5Y'], label='5-Year Average')
plt.legend()
plt.show()

# %%
cols = [
'Defense_Amount_Billions_USD',
'Education_Amount_Billions_USD',
'Health_Amount_Billions_USD',
'Infrastructure_Amount_Billions_USD',
'Agriculture_Amount_Billions_USD'
]

share = df[cols].div(df['Total_Budget_Billions_USD'], axis=0)*100
share.head()
# Out:
#    Defense_Amount_Billions_USD  Education_Amount_Billions_USD  \
# 0                    14.793784                      13.329348
# 1                    14.769493                      13.318156
# 2                    14.769648                      13.306233
# 3                    14.790914                      13.319566
# 4                    14.773845                      13.323500
#
#    Health_Amount_Billions_USD  Infrastructure_Amount_Billions_USD  \
# 0                    3.048416                           17.274357
# 1                    3.044963                           17.245304
# 2                    3.062331                           17.262873
# 3                    3.045947                           17.268973
# 4                    3.048181                           17.256637
#
#    Agriculture_Amount_Billions_USD
# 0                         8.637179
# 1                         8.622652
# 2                         8.617886
# 3                         8.621580
# ...

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(18,10))
sns.heatmap(corr, annot=True, cmap='RdBu_r')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

X = df[[
'Defense_Amount_Billions_USD',
'Education_Amount_Billions_USD',
'Health_Amount_Billions_USD',
'Infrastructure_Amount_Billions_USD',
'Agriculture_Amount_Billions_USD'
]]

y = df['Total_Budget_Billions_USD']

model = RandomForestRegressor(random_state=42)
model.fit(X, y)

importance = pd.Series(model.feature_importances_, index=X.columns)
importance.sort_values().plot(kind='barh')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

X_scaled = StandardScaler().fit_transform(X)

pca = PCA()
pca.fit(X_scaled)

print(pca.explained_variance_ratio_)
# Out:
# [9.88550358e-01 8.40636503e-03 2.44685170e-03 5.96403851e-04
#  2.17112951e-08]

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4, random_state=42)

df['Cluster'] = kmeans.fit_predict(X)

# %%
sns.scatterplot(
data=df,
x='Defense_Amount_Billions_USD',
y='Education_Amount_Billions_USD',
hue='Cluster',
palette='Set2'
)
# Out:
# <Axes: xlabel='Defense_Amount_Billions_USD', ylabel='Education_Amount_Billions_USD'>

# %%
from sklearn.linear_model import LinearRegression

X = df[['Year']]
y = df['Total_Budget_Billions_USD']

model = LinearRegression()
model.fit(X, y)

future = pd.DataFrame({'Year':[2027,2028,2029,2030]})

future['Prediction'] = model.predict(future)

print(future)
# Out:
#    Year  Prediction
# 0  2027  676.003777
# 1  2028  687.234448
# 2  2029  698.465119
# 3  2030  709.695790

# %%
Q1 = df['Total_Budget_Billions_USD'].quantile(0.25)
Q3 = df['Total_Budget_Billions_USD'].quantile(0.75)

IQR = Q3 - Q1

outliers = df[
(df['Total_Budget_Billions_USD'] < Q1 - 1.5*IQR) |
(df['Total_Budget_Billions_USD'] > Q3 + 1.5*IQR)
]

outliers
# Out:
#     Year  Defense_Percentage  Education_Percentage  Health_Percentage  \
# 70  2017                9.39                 15.81               3.66
# 71  2018                9.10                 16.64               3.68
# 72  2019                9.32                 14.82               3.85
# 74  2021                8.04                 14.92               4.46
# 75  2022                7.99                 14.16               4.71
# 76  2023                7.90                 14.16               4.59
# 77  2024                7.63                 14.16               4.59
# 78  2025                7.63                 14.16               4.59
# 79  2026                7.63                 14.16               4.59
#
#     Interest_Payments_Percentage  Total_Budget_Billions_USD  \
# 70                         19.83                    807.874
# 71                         19.40                    826.137
# 72                         23.23                    759.616
# ...

# %%
amount_cols = [
'Defense_Amount_Billions_USD',
'Education_Amount_Billions_USD',
'Health_Amount_Billions_USD',
'Infrastructure_Amount_Billions_USD',
'Agriculture_Amount_Billions_USD',
'Social_Welfare_Amount_Billions_USD'
]

df['Highest_Sector'] = df[amount_cols].idxmax(axis=1)

# %%
percentage_cols = [c for c in df.columns if 'Percentage' in c]

df[percentage_cols].std().sort_values()
# Out:
# Health_Percentage                       0.441976
# Social_Welfare_Percentage               0.719681
# State_Transfers_Percentage              0.719681
# Agriculture_Percentage                  0.719681
# Education_Percentage                    1.142745
# Administration_and_Others_Percentage    1.198611
# Infrastructure_Percentage               1.439323
# Defense_Percentage                      2.688018
# Interest_Payments_Percentage            6.293540
# dtype: float64

# %%
df['Decade'] = (df['Year']//10)*10

df.groupby('Decade')['Total_Budget_Billions_USD'].mean()
# Out:
# Decade
# 1940      3.516667
# 1950      4.872800
# 1960      8.352500
# 1970     19.842600
# 1980     64.589800
# 1990    101.622500
# 2000    257.174900
# 2010    652.197600
# 2020    942.264429
# Name: Total_Budget_Billions_USD, dtype: float64

# %%
sns.scatterplot(
data=df,
x='Defense_Percentage',
y='Defense_Amount_Billions_USD'
)
# Out:
# <Axes: xlabel='Defense_Percentage', ylabel='Defense_Amount_Billions_USD'>

# %% [markdown]
# Project: India Real Budget Analysis (Recommended)
#
# India Real Budget Analysis | Python, Pandas, NumPy, Matplotlib, Seaborn
#
# Performed comprehensive Exploratory Data Analysis (EDA) on India's Union Budget data (1947–2026), including data cleaning, univariate, bivariate, and multivariate analysis.
# Developed 20+ visualizations such as line charts, correlation heatmaps, scatter plots, pair plots, box plots, and trend analyses to identify expenditure patterns across sectors.
# Conducted advanced analytics, including year-over-year budget growth, CAGR, rolling averages, decade-wise analysis, sector contribution analysis, and outlier detection to derive actionable insights.
# Generated data-driven insights into long-term budget allocation trends for sectors including Defense, Education, Health, Infrastructure, and Agriculture, improving understanding of government spending patterns

# %% [markdown]
# | Step | Analysis              | Importance |
# | ---- | --------------------- | ---------- |
# | 1    | Data Cleaning         | ⭐⭐⭐⭐⭐      |
# | 2    | Univariate Analysis   | ⭐⭐⭐⭐⭐      |
# | 3    | Bivariate Analysis    | ⭐⭐⭐⭐⭐      |
# | 4    | Correlation Heatmap   | ⭐⭐⭐⭐⭐      |
# | 5    | Budget Growth Rate    | ⭐⭐⭐⭐⭐      |
# | 6    | CAGR                  | ⭐⭐⭐⭐⭐      |
# | 7    | Rolling Average       | ⭐⭐⭐⭐       |
# | 8    | Budget Composition    | ⭐⭐⭐⭐⭐      |
# | 9    | Decade-wise Analysis  | ⭐⭐⭐⭐       |
# | 10   | Outlier Detection     | ⭐⭐⭐⭐       |
# | 11   | Clustering (K-Means)  | ⭐⭐⭐⭐       |
# | 12   | PCA                   | ⭐⭐⭐⭐       |
# | 13   | Feature Importance    | ⭐⭐⭐⭐⭐      |
# | 14   | Budget Forecasting    | ⭐⭐⭐⭐⭐      |
# | 15   | Interactive Dashboard | ⭐⭐⭐⭐⭐      |
