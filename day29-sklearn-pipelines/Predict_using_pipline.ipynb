# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('model_pipe.pkl','rb'))

# %%
test_input2 = np.array([1, 'male', 29, 0, 0, 35.5000, 'S'], dtype=object).reshape(1, 7)

# %%
pipe.predict(test_input2)
# Out:
# C:\Users\sunil\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\sunil\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
